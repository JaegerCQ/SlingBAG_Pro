# %%
import torch
from torch.utils.cpp_extension import load
import numpy as np


differentiable_rapid_raditor = load(
    name="differentiable_rapid_raditor",
    sources=["utils/differentiable_rapid_raditor_kernel.cpp", "utils/differentiable_rapid_raditor_kernel_v4_fine.cu"],
    verbose=True,
)
# Out:
# Using /home/ultraman/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/ultraman/.cache/torch_extensions/py310_cu121/differentiable_rapid_raditor/build.ninja...
# Building extension module differentiable_rapid_raditor...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] c++ -MMD -MF differentiable_rapid_raditor_kernel.o.d -DTORCH_EXTENSION_NAME=differentiable_rapid_raditor -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include/TH -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include/THC -isystem /usr/local/cuda-11.8/include -isystem /home/ultraman/miniconda3/envs/SlingBAG/include/python3.10 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -c /home/ultraman/my_file/SlingBAG++_finger/utils/differentiable_rapid_raditor_kernel.cpp -o differentiable_rapid_raditor_kernel.o
# [2/3] /usr/local/cuda-11.8/bin/nvcc --generate-dependencies-with-compile --dependency-output differentiable_rapid_raditor_kernel_v4_fine.cuda.o.d -DTORCH_EXTENSION_NAME=differentiable_rapid_raditor -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include/TH -isystem /home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/include/THC -isystem /usr/local/cuda-11.8/include -isystem /home/ultraman/miniconda3/envs/SlingBAG/include/python3.10 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 --compiler-options '-fPIC' -std=c++17 -c /home/ultraman/my_file/SlingBAG++_finger/utils/differentiable_rapid_raditor_kernel_v4_fine.cu -o differentiable_rapid_raditor_kernel_v4_fine.cuda.o
# [3/3] c++ differentiable_rapid_raditor_kernel.o differentiable_rapid_raditor_kernel_v4_fine.cuda.o -shared -L/home/ultraman/miniconda3/envs/SlingBAG/lib/python3.10/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda-11.8/lib64 -lcudart -o differentiable_rapid_raditor.so
# Loading extension module differentiable_rapid_raditor...

# %%
# Define the custom Autograd Function
class SimulateFunction(torch.autograd.Function):
    
    @staticmethod
    def forward(ctx, sensor_location, source_location, source_p0, source_dx, dt, num_sensors, num_sources, num_times):
        # Call the C++ forward function
        simulate_record = differentiable_rapid_raditor.simulate(
            sensor_location, source_location, source_p0, source_dx, dt, num_sensors, num_sources, num_times)
        
        # Save inputs for backward
        ctx.save_for_backward(sensor_location, source_location, source_p0, source_dx)
        ctx.dt = dt
        ctx.num_sensors = num_sensors
        ctx.num_sources = num_sources
        ctx.num_times = num_times
        
        return simulate_record  # simulate_record：torch.Size([num_sensors * num_times])
    
    @staticmethod
    def backward(ctx, dL_dsimulate_record):
        # dL_dsimulate_record：torch.Size([num_sensors * num_times])
        sensor_location, source_location, source_p0, source_dx = ctx.saved_tensors
        dt = ctx.dt
        num_sensors = ctx.num_sensors
        num_sources = ctx.num_sources
        num_times = ctx.num_times


        # Call the C++ backward function
        grad_source_location, grad_source_p0, grad_source_dx = differentiable_rapid_raditor.simulate_backward(
            sensor_location, source_location, source_p0, source_dx, dL_dsimulate_record.contiguous(), dt, num_sensors, num_sources, num_times
        )
        return None, grad_source_location, grad_source_p0, grad_source_dx, None, None, None, None

# Utility function to use the custom autograd function
def simulate(sensor_location, source_location, source_p0, source_dx, dt, num_sensors, num_sources, num_times):
    return SimulateFunction.apply(sensor_location, source_location, source_p0, source_dx, dt, num_sensors, num_sources, num_times)

# %%
import torch
import numpy as np
from torch.autograd import Function
# from utils.dataset_loader import calculate_detector_location, read_one_dat_into_a_matrix
from utils.loss_utils import l2_loss, ssim
import torch.optim as optim
import trimesh
import random
from utils.sliding_ball_model_fine_flexible_array_cuda0 import SlidingBallModel  
from tqdm import tqdm
import matplotlib.pyplot as plt
import time
import os

device = torch.device('cuda:0')

def load_ply_vertices_faces(ply_path):
    """读取PLY文件中的顶点和面数据"""
    return trimesh.load(ply_path)

def load_point_cloud(file_path):
    balls = []
    with open(file_path, 'r') as file:
        lines = file.readlines()
        start = False
        for line in lines:
            if start:
                data = line.split()
                if len(data) == 5:
                    xyz = torch.tensor([float(data[0]), float(data[1]), float(data[2])], requires_grad=True, dtype=torch.float32, device=device)
                    pressure_0 = torch.tensor(float(data[3]), requires_grad=True, dtype=torch.float32, device=device)
                    radius = torch.tensor(float(data[4]), requires_grad=True, dtype=torch.float32, device=device)
                    ball = SlidingBallModel(xyz, pressure_0, radius)
                    balls.append(ball)
            if 'end_header' in line:
                start = True
    return balls

file_path = 'iteration_point_cloud_edition48/ball_120_after.ply'
balls = load_point_cloud(file_path)
print(f"{len(balls)} balls loaded from point cloud file.")

# 随机初始化球分布
def generate_random_balls(num_balls, boundaries, res):
    balls = []
    x_min, x_max, y_min, y_max, z_min, z_max = boundaries
    for _ in range(num_balls):
        xyz = torch.tensor([random.uniform(x_min, x_max), random.uniform(y_min, y_max), random.uniform(z_min, z_max)], requires_grad=False, dtype=torch.float32, device=device)
        pressure_0 = torch.tensor(random.uniform(20, 180), requires_grad=True, dtype=torch.float32, device=device)
        radius = torch.tensor(random.uniform(1*res, 12*res), requires_grad=True, dtype=torch.float32, device=device)
        ball = SlidingBallModel(xyz, pressure_0, radius)
        balls.append(ball)
    return balls

# 迭代函数
def run_iterations(balls, pressure_threshold, radius_max_threshold, radius_min_threshold, mesh):
    new_balls = []
    for ball in balls:
        new_ball = ball.adaptive_density_optimization(pressure_threshold, radius_max_threshold, radius_min_threshold, mesh)
        if new_ball is not None:
            new_balls.append(new_ball)
    balls = [ball for ball in balls if not ball._is_destroyed] + new_balls
    return balls

# 保存点云数据函数
def save_point_cloud(balls, filename):
    points = []
    for ball in balls:
        if not ball._is_destroyed:
            xyz = ball._xyz.detach().cpu().numpy()  # 转为 numpy 数组
            pressure_0 = ball._pressure_0.item()  # 提取标量值
            radius = ball._radius.item()  # 提取标量值
            points.append([xyz[0], xyz[1], xyz[2], pressure_0, radius])

    with open(filename, "w") as ply_file:
        # 写 PLY 文件头
        ply_file.write("ply\n")
        ply_file.write("format ascii 1.0\n")
        ply_file.write(f"element vertex {len(points)}\n")
        ply_file.write("property float x\n")
        ply_file.write("property float y\n")
        ply_file.write("property float z\n")
        ply_file.write("property float pressure_0\n")
        ply_file.write("property float radius\n")
        ply_file.write("end_header\n")
        
        # 写入每个点的信息
        for point in points:
            ply_file.write(f"{point[0]} {point[1]} {point[2]} {point[3]} {point[4]}\n")

# 参数设置

num_times = 4096
Nt = num_times
res = 0.20e-3
Vs = 1500.0
dt = 25e-9  # [s]
# num_balls = 600000
folder_name = "iteration_point_cloud_edition60"
boundaries = (-12.8e-3, 12.8e-3, -12.8e-3, 12.8e-3, -12.8e-3, 12.8e-3)
os.makedirs(folder_name, exist_ok=True)
# # 进行初始化，并提取初始化声源的信息
# balls = generate_random_balls(num_balls, boundaries, res)
# source_num = num_balls
source_num = len(balls)
mesh_path = "data/finger_loose_cover_small_252verticles.ply"
mesh = trimesh.load(mesh_path)  # 确保文件路径正确
print(f"Mesh loaded with {len(mesh.vertices)} vertices")

# 检查bounds是否有效
bounds = mesh.bounds
print(f"Mesh bounds: {bounds}")


pressure_threshold = 15.0
radius_max_threshold = 3 * res
radius_min_threshold = 0.5 * res

# sensor_num = 1000
# sensor_location = np.zeros((sensor_num, 3), dtype=np.float32)
# real_signal = np.zeros((sensor_num, Nt), dtype=np.float32)

# for i in range(sensor_num):
#     num = i * 200
#     sensor_location[i] = sensor_matrix_location[num]
#     real_signal[i] = sensor_matrix_data[num]
# Out:
# /home/ultraman/my_file/SlingBAG++_finger/utils/sliding_ball_model_fine_flexible_array_cuda1.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self._xyz = Parameter(torch.tensor(xyz, dtype=torch.float32) if xyz is not None else torch.empty(0))
# /home/ultraman/my_file/SlingBAG++_finger/utils/sliding_ball_model_fine_flexible_array_cuda1.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self._pressure_0 = Parameter(torch.tensor(pressure_0, dtype=torch.float32) if pressure_0 is not None else torch.empty(0))
# /home/ultraman/my_file/SlingBAG++_finger/utils/sliding_ball_model_fine_flexible_array_cuda1.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self._radius = Parameter(torch.tensor(radius, dtype=torch.float32) if radius is not None else torch.empty(0))
# 60412 balls loaded from point cloud file.
# Mesh loaded with 106 vertices
# Mesh bounds: [[ 0.012603   -0.004       0.013264  ]
#  [ 0.03522741  0.104337    0.08300044]]

# %%
# 读取sensor_data_matrix.txt文件
sensor_data_matrix = np.loadtxt('data/sensor_signal_2006elements_4096.txt', delimiter='\t')
real_signal = sensor_data_matrix#[0:1009:2, :]
sensor_location = np.loadtxt('data/sensor_location_2006elements.txt', delimiter='\t')
sensor_location = sensor_location#[0:1009:2, :]
sensor_num = sensor_location.shape[0]

print(f"GT:{real_signal.shape}")
print(f"location:{sensor_location.shape}")
# Out:
# GT:(2006, 4096)
# location:(2006, 3)

# %%
# 将数据转为PyTorch张量，并移动到GPU
sensor_location = torch.tensor(sensor_location,dtype=torch.float, device=device)
real_signal = torch.tensor(real_signal,dtype=torch.float)
real_signal_flat = real_signal.flatten()
real_signal_flat = real_signal_flat.to(device)

# 将所有参数按照不同学习率进行分组
def get_optim_params(balls):
    params_xyz = [ball._xyz for ball in balls]
    params_pressure = [ball._pressure_0 for ball in balls]
    params_radius = [ball._radius for ball in balls]
    return [
        # {'params': params_pressure, 'lr': 0.05},
        # {'params': params_radius, 'lr': 0.00004},
        {'params': params_xyz, 'lr': 0.000005},
        {'params': params_pressure, 'lr': 0.005},
        {'params': params_radius, 'lr': 0.000005},
    ]

optimizer = optim.Adam(get_optim_params(balls), betas=(0.9, 0.999))

# 设置学习率调度器
# lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.9)

num_iterations = 1000

# 开始迭代训练
for iter in range(num_iterations):
    if (iter + 1) % 80 <= 40 and (iter + 1) % 80 > 0:
        downsample_factor = 16
        ds_num_times = num_times//downsample_factor
        ds_dt = dt*downsample_factor
        ds_real_signal = real_signal[:, ::downsample_factor,]

    if (iter + 1) % 80 <= 60 and (iter + 1) % 80 > 40:
        downsample_factor = 4
        ds_num_times = num_times//downsample_factor
        ds_dt = dt*downsample_factor
        ds_real_signal = real_signal[:, ::downsample_factor,]

    if (iter + 1) % 80 > 60 or (iter + 1) % 80 == 0:
        downsample_factor = 1
        ds_num_times = num_times//downsample_factor
        ds_dt = dt*downsample_factor
        ds_real_signal = real_signal[:, ::downsample_factor,]

    ds_real_signal_flat = ds_real_signal.flatten()
    ds_real_signal_flat = ds_real_signal_flat.to(device)
    start_time = time.time()  # 记录开始时间
    optimizer.zero_grad()

    # 使用当前球的参数传递给simulate函数
    source_location = torch.stack([ball._xyz for ball in balls]).flatten()
    source_p0 = torch.stack([ball._pressure_0 for ball in balls]).flatten()
    radius_0 = torch.stack([ball._radius for ball in balls]).flatten()
    
    simulate_record = simulate(sensor_location, source_location, source_p0, radius_0, ds_dt, sensor_num, source_num, ds_num_times)  
    loss = l2_loss(simulate_record, ds_real_signal_flat)
    # if iter ==0:
    #     print(f"迭代 {iter}，损失: {loss.item()}")
        
    loss.backward()
    optimizer.step()
    # lr_scheduler.step()
    
    # print(f"迭代 {iter + 1}，损失: {loss.item()}")
    end_time = time.time()  # 记录结束时间
    iteration_time = end_time - start_time  # 计算时间差
    print(f"迭代 {iter + 1}，损失: {loss.item()}，时间: {iteration_time}")
    # 更新每个球的参数，以确保它们在相应的实例中
    for ball in balls:
        ball._xyz.data = ball._xyz.data.requires_grad_(True)
        ball._pressure_0.data = ball._pressure_0.data.requires_grad_(True)
        ball._radius.data = ball._radius.data.requires_grad_(True)

    # 每10次迭代前保存点云数据到文件
    if (iter + 1) % 10 == 0:
        filename = f"ball_{iter + 1}_before.ply"
        full_path = os.path.join(folder_name, filename)
        save_point_cloud(balls, full_path)
        print(f"Point cloud saved to {filename}")

    # 每20次迭代进行自适应密度优化
    if (iter + 1) % 20 == 0:
        with torch.no_grad():
            # 更新每个球的梯度状态，为下一次分裂做准备
            for ball in balls:
                ball._xyz.grad = ball._xyz.grad / torch.norm(ball._xyz.grad, p=2) if ball._xyz.grad is not None else None

            balls = run_iterations(balls, pressure_threshold, radius_max_threshold, radius_min_threshold, mesh)
            source_num = len(balls)  # 更新 source_num 为当前球的数量

        # 打印当前球的数量
        print(f"After {iter + 1} iterations, number of balls: {source_num}")

        # 更新优化器中的参数
        optimizer = optim.Adam(get_optim_params(balls), betas=(0.9, 0.999))
        # lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.9)

    # 每10次迭代后保存点云数据到文件
    if (iter + 1) % 10 == 0:
        filename = f"ball_{iter + 1}_after.ply"
        full_path = os.path.join(folder_name, filename)
        save_point_cloud(balls, full_path)
        print(f"Point cloud saved to {filename}")

    if (iter + 1) % 80 == 0:
        with torch.no_grad():
            new_balls = []
            for ball in balls:
                if ball._xyz.grad is not None:
                    gradient_direction = ball._xyz.grad
                    new_ball = ball.clone_along_gradient(gradient_direction, mesh,res)
                    if new_ball is not None:
                        new_balls.append(new_ball)
            balls.extend(new_balls)
            source_num = len(balls)  # 更新 source_num 为当前球的数量

        # 打印当前球的数量
        print(f"After {iter + 1} iterations with cloning, number of balls: {source_num}")

        # 更新优化器中的参数
        optimizer = optim.Adam(get_optim_params(balls), betas=(0.9, 0.999))
        # lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.9)
        # 保存点云
        filename = f"ball_{iter + 1}_after_duplication.ply"
        full_path = os.path.join(folder_name, filename)
        save_point_cloud(balls, full_path)
        print(f"Point cloud saved to {filename}")
# print("迭代后球的信息:")
# for ball in balls:
#     print(ball.get_attributes())
    # 在每次迭代完成后进行评估
    # if (iter + 1) % 15 == 0:
    #     with torch.no_grad():
    #         # 选择一批数据点进行评估
    #         step_x = 35
    #         step_y = 35
    #         sensor_location_eval = sensor_matrix_location_for_sample[::step_x, ::step_y, :].reshape(-1, 3)
    #         real_signal_eval = sensor_matrix_data_for_sample[::step_x, ::step_y, :].reshape(-1, Nt)
    #         sensor_num_eval = sensor_location_eval.shape[0]

    #         sensor_location_eval = torch.tensor(sensor_location_eval, device=device)  # 不用添加batch维度
    #         real_signal_eval = torch.tensor(real_signal_eval, device=device)  # 不需要flatten

    #         # 使用选定的评估点进行模拟
    #         simulate_record_eval = simulate(sensor_location_eval, source_location, source_p0, radius_0, dt, sensor_num_eval, source_num, num_times)
    #         eval_loss = l2_loss(simulate_record_eval, real_signal_eval.flatten())
    #         print(f"验证集评估损失: {eval_loss.item()}")
# Out:
# 迭代 1，损失: 55.74308395385742，时间: 11.783432722091675
# 迭代 2，损失: 51.50980758666992，时间: 7.2784459590911865
# 迭代 3，损失: 47.745697021484375，时间: 7.592429876327515
# 迭代 4，损失: 44.5835075378418，时间: 7.6024298667907715
# 迭代 5，损失: 41.90980911254883，时间: 7.295382022857666
# 迭代 6，损失: 39.61110305786133，时间: 7.637194871902466
# 迭代 7，损失: 37.621803283691406，时间: 7.297585725784302
# 迭代 8，损失: 35.88198471069336，时间: 7.610962629318237
# 迭代 9，损失: 34.38785171508789，时间: 7.638879060745239
# 迭代 10，损失: 33.112667083740234，时间: 7.2998573780059814
# Point cloud saved to ball_10_before.ply
# Point cloud saved to ball_10_after.ply
# 迭代 11，损失: 31.992246627807617，时间: 7.637917757034302
# 迭代 177，损失: 74.30821990966797，时间: 32.46973729133606
# 迭代 178，损失: 66.0450668334961，时间: 30.675456523895264
# 迭代 179，损失: 59.07146453857422，时间: 32.42166471481323
# 迭代 180，损失: 53.18742370605469，时间: 32.51892066001892
# Point cloud saved to ball_180_before.ply
# After 180 iterations, number of balls: 242292
# Point cloud saved to ball_180_after.ply
# 迭代 181，损失: 48.177452087402344，时间: 48.50802254676819
# 迭代 182，损失: 43.417572021484375，时间: 32.58959460258484
# 迭代 183，损失: 37.41434097290039，时间: 30.366395473480225
# 迭代 184，损失: 32.599849700927734，时间: 32.31889271736145
# 迭代 185，损失: 28.753925323486328，时间: 32.530517578125
# 迭代 186，损失: 25.657625198364258，时间: 30.501846075057983
# 迭代 187，损失: 23.14776039123535，时间: 32.508376359939575
# 迭代 188，损失: 21.077770233154297，时间: 32.494065284729004
# 迭代 189，损失: 19.359174728393555，时间: 30.54158902168274
# 迭代 190，损失: 17.908267974853516，时间: 32.46614122390747
# Point cloud saved to ball_190_before.ply
# Point cloud saved to ball_190_after.ply
# 迭代 191，损失: 16.703493118286133，时间: 32.55236268043518
# 迭代 192，损失: 15.671627044677734，时间: 32.459155559539795
# 迭代 193，损失: 14.769664764404297，时间: 30.564260721206665
# 迭代 194，损失: 13.98781967163086，时间: 32.626073360443115
# 迭代 195，损失: 13.29928207397461，时间: 32.714781761169434
# 迭代 196，损失: 12.683178901672363，时间: 30.54060459136963
# 迭代 197，损失: 12.137579917907715，时间: 32.55055570602417
# 迭代 198，损失: 11.637345314025879，时间: 32.69886827468872
# 迭代 199，损失: 11.179065704345703，时间: 30.482643127441406
# 迭代 200，损失: 10.759081840515137，时间: 32.46620011329651
# Point cloud saved to ball_200_before.ply
# After 200 iterations, number of balls: 237530
# Point cloud saved to ball_200_after.ply
# 迭代 201，损失: 16.32767105102539，时间: 92.75196170806885
# 迭代 202，损失: 15.345721244812012，时间: 76.00114369392395
# 迭代 203，损失: 14.213910102844238，时间: 73.80057692527771
# 迭代 204，损失: 13.295635223388672，时间: 75.57606172561646
# 迭代 205，损失: 12.520312309265137，时间: 76.23514723777771
# 迭代 206，损失: 11.851227760314941，时间: 73.98589968681335
# 迭代 207，损失: 11.259393692016602，时间: 75.86140871047974
# 迭代 208，损失: 10.730422973632812，时间: 75.66038703918457
# 迭代 209，损失: 10.253485679626465，时间: 73.53048729896545
# 迭代 210，损失: 9.8164644241333，时间: 76.04225969314575
# Point cloud saved to ball_210_before.ply
# Point cloud saved to ball_210_after.ply
# 迭代 211，损失: 9.41702651977539，时间: 76.06309676170349
# 迭代 212，损失: 9.051789283752441，时间: 76.24480438232422
# 迭代 213，损失: 8.71016788482666，时间: 73.8575177192688
# 迭代 214，损失: 8.389243125915527，时间: 75.65565299987793
# 迭代 215，损失: 8.092050552368164，时间: 75.9517457485199
# 迭代 216，损失: 7.816333293914795，时间: 73.57489681243896
# 迭代 217，损失: 7.556357383728027，时间: 76.09356951713562
# 迭代 218，损失: 7.313100814819336，时间: 76.23359799385071
# 迭代 219，损失: 7.08367919921875，时间: 73.65209817886353
# 迭代 220，损失: 6.868335247039795，时间: 76.46316123008728
# Point cloud saved to ball_220_before.ply
# After 220 iterations, number of balls: 229710
# Point cloud saved to ball_220_after.ply
# 迭代 221，损失: 7.7479448318481445，时间: 253.6335587501526
# 迭代 222，损失: 7.447702884674072，时间: 234.8233335018158
# 迭代 223，损失: 6.964107513427734，时间: 237.35039114952087
# 迭代 224，损失: 6.536398887634277，时间: 234.6941957473755
# 迭代 225，损失: 6.161012172698975，时间: 237.26382994651794
# 迭代 226，损失: 5.818227767944336，时间: 237.08043789863586
# 迭代 227，损失: 5.505054950714111，时间: 234.59395933151245
# 迭代 228，损失: 5.217176914215088，时间: 237.0950448513031
# 迭代 229，损失: 4.953923225402832，时间: 237.006578207016
# 迭代 230，损失: 4.7098774909973145，时间: 234.87076902389526
# Point cloud saved to ball_230_before.ply
# Point cloud saved to ball_230_after.ply
# 迭代 231，损失: 4.485161304473877，时间: 234.4485800266266
# 迭代 232，损失: 4.277894020080566，时间: 237.08163952827454
# 迭代 233，损失: 4.085254669189453，时间: 234.854642868042
# 迭代 234，损失: 3.906970739364624，时间: 237.14575457572937
# 迭代 235，损失: 3.7409958839416504，时间: 237.20722699165344
# 迭代 236，损失: 3.5874431133270264，时间: 235.126610994339
# 迭代 237，损失: 3.443692445755005，时间: 237.29523634910583
# 迭代 238，损失: 3.3095922470092773，时间: 237.30488348007202
# 迭代 239，损失: 3.184314012527466，时间: 234.89262890815735
# 迭代 240，损失: 3.0672342777252197，时间: 237.38592314720154
# Point cloud saved to ball_240_before.ply
# After 240 iterations, number of balls: 220028
# Point cloud saved to ball_240_after.ply
# After 240 iterations with cloning, number of balls: 439896
# Point cloud saved to ball_240_after_duplication.ply
# 迭代 241，损失: 579.808349609375，时间: 91.43115735054016
# 迭代 242，损失: 495.72332763671875，时间: 54.23863458633423
# 迭代 243，损失: 423.6857604980469，时间: 57.67713189125061
# 迭代 244，损失: 363.9420471191406，时间: 57.68708944320679
# 迭代 245，损失: 312.98321533203125，时间: 58.00454664230347
# 迭代 246，损失: 268.8853454589844，时间: 54.4290874004364
# 迭代 247，损失: 230.58645629882812，时间: 57.925342321395874
# 迭代 248，损失: 197.14642333984375，时间: 58.16816210746765
# 迭代 249，损失: 168.13502502441406，时间: 54.2607581615448
# 迭代 250，损失: 143.110107421875，时间: 57.614004611968994
# Point cloud saved to ball_250_before.ply
# Point cloud saved to ball_250_after.ply
# 迭代 251，损失: 121.66117095947266，时间: 57.88335466384888
# 迭代 252，损失: 103.44794464111328，时间: 58.12779760360718
# 迭代 253，损失: 88.10005950927734，时间: 54.23831486701965
# 迭代 254，损失: 75.22673034667969，时间: 57.54771137237549
# 迭代 255，损失: 64.51058197021484，时间: 58.04925513267517
# 迭代 256，损失: 55.688026428222656，时间: 54.38585329055786
# 迭代 257，损失: 48.46632385253906，时间: 58.12207531929016
# 迭代 258，损失: 42.579261779785156，时间: 57.88008093833923
# 迭代 259，损失: 37.812408447265625，时间: 54.36956548690796
# 迭代 260，损失: 34.00761795043945，时间: 57.74710154533386
# Point cloud saved to ball_260_before.ply
# After 260 iterations, number of balls: 421344
# Point cloud saved to ball_260_after.ply
# 迭代 261，损失: 30.971485137939453，时间: 87.56254935264587
# 迭代 262，损失: 27.328718185424805，时间: 56.930344104766846
# 迭代 263，损失: 22.438812255859375，时间: 52.89918613433838
# 迭代 264，损失: 18.70634651184082，时间: 56.51415157318115
# 迭代 265，损失: 15.839265823364258，时间: 56.82727074623108
# 迭代 266，损失: 13.608692169189453，时间: 52.93501377105713
# 迭代 267，损失: 11.864710807800293，时间: 56.497623920440674
# 迭代 268，损失: 10.483183860778809，时间: 56.67205286026001
# 迭代 269，损失: 9.400114059448242，时间: 52.966675996780396
# 迭代 270，损失: 8.538240432739258，时间: 56.60275650024414
# Point cloud saved to ball_270_before.ply
# Point cloud saved to ball_270_after.ply
# 迭代 271，损失: 7.8320770263671875，时间: 56.551170110702515
# 迭代 272，损失: 7.244318962097168，时间: 56.87322664260864
# 迭代 273，损失: 6.745563983917236，时间: 56.886502265930176
# 迭代 274，损失: 6.312328338623047，时间: 53.12269449234009
# 迭代 275，损失: 5.9320387840271，时间: 57.00122404098511
# 迭代 276，损失: 5.581462860107422，时间: 53.06649613380432
# 迭代 277，损失: 5.266360282897949，时间: 56.50910806655884
# 迭代 278，损失: 4.97913122177124，时间: 56.810641050338745
# 迭代 279，损失: 4.715949535369873，时间: 57.00258183479309
# 迭代 280，损失: 4.475832462310791，时间: 53.0225088596344
# Point cloud saved to ball_280_before.ply
# After 280 iterations, number of balls: 406643
# Point cloud saved to ball_280_after.ply
# 迭代 281，损失: 10.4017333984375，时间: 153.64099526405334
# 迭代 282，损失: 9.117006301879883，时间: 125.75097465515137
# 迭代 283，损失: 8.146857261657715，时间: 125.87286019325256
# 迭代 284，损失: 7.402702331542969，时间: 122.21484994888306
# 迭代 285，损失: 6.800969123840332，时间: 126.31846284866333
# 迭代 286，损失: 6.314747333526611，时间: 122.6018443107605
# 迭代 287，损失: 5.900591850280762，时间: 126.06236863136292
# 迭代 288，损失: 5.53639554977417，时间: 126.18738627433777
# 迭代 289，损失: 5.211416244506836，时间: 122.39853119850159
# 迭代 290，损失: 4.921469211578369，时间: 125.69419860839844
# Point cloud saved to ball_290_before.ply
# Point cloud saved to ball_290_after.ply
# 迭代 291，损失: 4.657422065734863，时间: 126.18489289283752
# 迭代 292，损失: 4.4205732345581055，时间: 126.21043658256531
# 迭代 293，损失: 4.20326042175293，时间: 122.02839374542236
# 迭代 294，损失: 4.002622604370117，时间: 125.84023928642273
# 迭代 295，损失: 3.816141366958618，时间: 126.15083408355713
# 迭代 296，损失: 3.644747495651245，时间: 126.1455602645874
# 迭代 297，损失: 3.4861643314361572，时间: 122.72840118408203
# 迭代 298，损失: 3.3392155170440674，时间: 129.42373609542847
# 迭代 299，损失: 3.2029950618743896，时间: 122.35045599937439
# 迭代 300，损失: 3.0751821994781494，时间: 126.81931471824646
# Point cloud saved to ball_300_before.ply
# After 300 iterations, number of balls: 385346
# Point cloud saved to ball_300_after.ply
# 迭代 301，损失: 3.990628242492676，时间: 420.1535818576813
# 迭代 302，损失: 3.861891508102417，时间: 392.2094612121582
# 迭代 303，损失: 3.5363807678222656，时间: 387.822140455246
# 迭代 304，损失: 3.25400710105896，时间: 391.73333406448364
# 迭代 305，损失: 3.0277562141418457，时间: 392.08636021614075
# 迭代 306，损失: 2.825853109359741，时间: 388.1682176589966
# 迭代 307，损失: 2.642101764678955，时间: 391.6981530189514
# 迭代 308，损失: 2.479262351989746，时间: 392.5060815811157
# 迭代 309，损失: 2.332099676132202，时间: 387.7134130001068
# 迭代 310，损失: 2.199127674102783，时间: 392.52881050109863
# Point cloud saved to ball_310_before.ply
# Point cloud saved to ball_310_after.ply
# 迭代 311，损失: 2.0780723094940186，时间: 392.121089220047
# 迭代 312，损失: 1.9674068689346313，时间: 393.34999656677246
# 迭代 313，损失: 1.8659569025039673，时间: 388.30036664009094
# 迭代 314，损失: 1.7737836837768555，时间: 392.3520278930664
# 迭代 315，损失: 1.6885175704956055，时间: 388.11408615112305
# 迭代 316，损失: 1.6097501516342163，时间: 391.67693400382996
# 迭代 317，损失: 1.5372761487960815，时间: 392.2844841480255
# 迭代 318，损失: 1.4706454277038574，时间: 388.46597170829773
# 迭代 319，损失: 1.4086729288101196，时间: 391.80135345458984
# 迭代 320，损失: 1.3515921831130981，时间: 392.36060857772827
# Point cloud saved to ball_320_before.ply
# After 320 iterations, number of balls: 363952
# Point cloud saved to ball_320_after.ply
# After 320 iterations with cloning, number of balls: 727707
# Point cloud saved to ball_320_after_duplication.ply
# 迭代 321，损失: 581.0643310546875，时间: 153.32698321342468
# 迭代 322，损失: 483.47998046875，时间: 90.2168562412262
# 迭代 323，损失: 401.9101257324219，时间: 96.14676237106323
# 迭代 324，损失: 336.0047607421875，时间: 96.92692303657532
# 迭代 325，损失: 281.0458679199219，时间: 90.40744018554688
# 迭代 326，损失: 234.62149047851562，时间: 96.7345130443573
# 迭代 327，损失: 195.08477783203125，时间: 96.88714218139648
# 迭代 328，损失: 161.71661376953125，时间: 90.58206272125244
# 迭代 329，损失: 133.58468627929688，时间: 96.42926406860352
# 迭代 330，损失: 110.2093276977539，时间: 96.84424495697021
# Point cloud saved to ball_330_before.ply
# Point cloud saved to ball_330_after.ply
# 迭代 331，损失: 90.93318176269531，时间: 96.86941695213318
# 迭代 332，损失: 75.1573715209961，时间: 90.6803150177002
# 迭代 333，损失: 62.42880630493164，时间: 96.58941388130188
# 迭代 334，损失: 52.257179260253906，时间: 96.98606085777283
# 迭代 335，损失: 44.191123962402344，时间: 90.42663979530334
# 迭代 336，损失: 37.851470947265625，时间: 96.4936535358429
# 迭代 337，损失: 32.90991973876953，时间: 96.73674464225769
# 迭代 338，损失: 29.076269149780273，时间: 90.85059094429016
# 迭代 339，损失: 26.07291603088379，时间: 96.81551122665405
# 迭代 340，损失: 23.732229232788086，时间: 96.81669068336487
# Point cloud saved to ball_340_before.ply
# After 340 iterations, number of balls: 673040
# Point cloud saved to ball_340_after.ply
# 迭代 341，损失: 22.349557876586914，时间: 139.4442195892334
# 迭代 342，损失: 18.53162384033203，时间: 92.45048785209656
# 迭代 343，损失: 14.271095275878906，时间: 93.1072006225586
# 迭代 344，损失: 11.430044174194336，时间: 86.6508138179779
# 迭代 345，损失: 9.365065574645996，时间: 92.86548376083374
# 迭代 346，损失: 7.741292953491211，时间: 93.69769191741943
# 迭代 347，损失: 6.460490703582764，时间: 86.49941730499268
# 迭代 348，损失: 5.463379383087158，时间: 92.89219856262207
# 迭代 349，损失: 4.719993591308594，时间: 93.47589206695557
# 迭代 350，损失: 4.157057762145996，时间: 86.74987816810608
# Point cloud saved to ball_350_before.ply
# Point cloud saved to ball_350_after.ply
# 迭代 351，损失: 3.722350597381592，时间: 86.36371684074402
# 迭代 352，损失: 3.365555763244629，时间: 93.15271353721619
# 迭代 353，损失: 3.057983636856079，时间: 93.54046940803528
# 迭代 354，损失: 2.792673349380493，时间: 86.60947275161743
# 迭代 355，损失: 2.553401231765747，时间: 93.27734446525574
# 迭代 356，损失: 2.341233015060425，时间: 93.63694953918457
# 迭代 357，损失: 2.154252052307129，时间: 86.00410628318787
# 迭代 358，损失: 1.9882230758666992，时间: 92.87515640258789
# 迭代 359，损失: 1.8388890027999878，时间: 92.95967316627502
# 迭代 360，损失: 1.70383620262146，时间: 86.43471765518188
# Point cloud saved to ball_360_before.ply
# After 360 iterations, number of balls: 634626
# Point cloud saved to ball_360_after.ply
# 迭代 361，损失: 8.582143783569336，时间: 244.61976194381714
# 迭代 362，损失: 6.433592796325684，时间: 200.9427227973938
# 迭代 363，损失: 5.385387897491455，时间: 193.55516958236694
# 迭代 364，损失: 4.686441421508789，时间: 200.53830933570862
# 迭代 365，损失: 4.125313758850098，时间: 200.93767428398132
# 迭代 366，损失: 3.6909384727478027，时间: 194.27405214309692
# 迭代 367，损失: 3.3462839126586914，时间: 201.1202096939087
# 迭代 368，损失: 3.0622599124908447，时间: 201.0515856742859
# 迭代 369，损失: 2.8178389072418213，时间: 193.57930374145508
# 迭代 370，损失: 2.6059699058532715，时间: 200.33606481552124
# Point cloud saved to ball_370_before.ply
# Point cloud saved to ball_370_after.ply
# 迭代 371，损失: 2.423933744430542，时间: 203.417950630188
# 迭代 372，损失: 2.2623422145843506，时间: 194.44181418418884
# 迭代 373，损失: 2.114549160003662，时间: 200.93462085723877
# 迭代 374，损失: 1.9828311204910278，时间: 204.05173254013062
# 迭代 375，损失: 1.8649463653564453，时间: 193.75711035728455
# 迭代 376，损失: 1.7564866542816162，时间: 200.29007649421692
# 迭代 377，损失: 1.6585638523101807，时间: 204.21123552322388
# 迭代 378，损失: 1.5684187412261963，时间: 194.726989030838
# 迭代 379，损失: 1.4852778911590576，时间: 200.9909508228302
# 迭代 380，损失: 1.4085983037948608，时间: 204.29576563835144
# Point cloud saved to ball_380_before.ply
# After 380 iterations, number of balls: 589051
# Point cloud saved to ball_380_after.ply
# 迭代 381，损失: 2.26255464553833，时间: 644.8532388210297
# 迭代 382，损失: 2.3944811820983887，时间: 607.9243085384369
# 迭代 383，损失: 2.0221142768859863，时间: 604.7158169746399
# 迭代 384，损失: 1.8728594779968262，时间: 599.0062050819397
# 迭代 385，损失: 1.6706575155258179，时间: 605.5164065361023
# 迭代 386，损失: 1.5623843669891357，时间: 599.1759209632874
# 迭代 387，损失: 1.4560133218765259，时间: 605.9477195739746
# 迭代 388，损失: 1.3472394943237305，时间: 611.1534721851349
# 迭代 389，损失: 1.262495994567871，时间: 597.5011913776398
# 迭代 390，损失: 1.187688946723938，时间: 610.3571486473083
# Point cloud saved to ball_390_before.ply
# Point cloud saved to ball_390_after.ply
# 迭代 391，损失: 1.1158448457717896，时间: 607.082081079483
# 迭代 392，损失: 1.053122639656067，时间: 606.7824347019196
# 迭代 393，损失: 0.9971194863319397，时间: 599.1048340797424
# 迭代 394，损失: 0.9443333745002747，时间: 608.8889117240906
# 迭代 395，损失: 0.8963433504104614，时间: 599.3963279724121
# 迭代 396，损失: 0.8528106808662415，时间: 607.4631986618042
# 迭代 397，损失: 0.8127393126487732，时间: 610.1152739524841
# 迭代 398，损失: 0.775688111782074，时间: 598.8088412284851
# 迭代 399，损失: 0.7411249876022339，时间: 607.4740331172943
# 迭代 400，损失: 0.7093685865402222，时间: 609.7292261123657
# Point cloud saved to ball_400_before.ply
# After 400 iterations, number of balls: 554031
# Point cloud saved to ball_400_after.ply
# After 400 iterations with cloning, number of balls: 1107885
# Point cloud saved to ball_400_after_duplication.ply
# 迭代 401，损失: 584.0502319335938，时间: 230.41770219802856
# 迭代 402，损失: 474.0992431640625，时间: 149.9025228023529
# 迭代 403，损失: 383.333740234375，时间: 150.32919478416443
# 迭代 404，损失: 311.3800964355469，时间: 140.7469425201416
# 迭代 405，损失: 252.74066162109375，时间: 149.9877278804779
# 迭代 406，损失: 204.38790893554688，时间: 150.37633156776428
# 迭代 407，损失: 164.56617736816406，时间: 150.87818360328674
# 迭代 408，损失: 131.88369750976562，时间: 141.24957299232483
# 迭代 409，损失: 105.53845977783203，时间: 150.9915735721588
# 迭代 410，损失: 84.55279541015625，时间: 150.61641240119934
# Point cloud saved to ball_410_before.ply
# Point cloud saved to ball_410_after.ply
# 迭代 411，损失: 68.08326721191406，时间: 150.7399616241455
# 迭代 412，损失: 55.24906539916992，时间: 140.89585733413696
# 迭代 413，损失: 45.4658088684082，时间: 150.3503143787384
# 迭代 414，损失: 38.03984451293945，时间: 150.591694355011
# 迭代 415，损失: 32.465370178222656，时间: 140.84267783164978
# 迭代 416，损失: 28.348934173583984，时间: 150.60904932022095
# 迭代 417，损失: 25.238195419311523，时间: 150.91321206092834
# 迭代 418，损失: 22.85762596130371，时间: 141.08703565597534
# 迭代 419，损失: 20.984216690063477，时间: 150.32545590400696
# 迭代 420，损失: 19.43589210510254，时间: 150.7754499912262
# Point cloud saved to ball_420_before.ply
# After 420 iterations, number of balls: 976600
# Point cloud saved to ball_420_after.ply

# %% [markdown]
# 680应该是极限了
